# %%
import pandas as pd

# %%
df = pd.read_csv('data/train.csv')
df.head()
# Out:
#                          observation_id           Type  \
# 0  34d76816-cfc2-4bdd-b3a2-bf0c40b12689  Person search
# 1  83c87ec1-e6d4-4bbb-8e0c-159516706359  Person search
# 2  8c2eae4b-035a-492f-92d6-cd27e6c900a1  Person search
# 3  e63a036a-a728-4efe-8e08-7198f56d6d0a  Person search
# 4  40c70aca-1f7f-4efe-8c5b-ade0f2e9937d  Person search
#
#                         Date Part of a policing operation   Latitude  \
# 0  2019-12-01T00:00:00+00:00                         True        NaN
# 1  2019-12-01T00:09:00+00:00                         True        NaN
# 2  2019-12-01T00:10:00+00:00                         True        NaN
# 3  2019-12-01T00:10:00+00:00                        False        NaN
# 4  2019-12-01T00:12:00+00:00                         True  50.368247
#
#    Longitude  Gender Age range  \
# 0        NaN    Male     18-24
# 1        NaN    Male     18-24
# 2        NaN  Female     18-24
# 3        NaN    Male     18-24
# 4  -4.126646    Male     18-24
#
# ...

# %%
df.columns
# Out:
# Index(['observation_id', 'Type', 'Date', 'Part of a policing operation',
#        'Latitude', 'Longitude', 'Gender', 'Age range',
#        'Self-defined ethnicity', 'Officer-defined ethnicity', 'Legislation',
#        'Object of search', 'Outcome', 'Outcome linked to object of search',
#        'Removal of more than just outer clothing', 'station'],
#       dtype='object')

# %%
rest = ['Type',  'Part of a policing operation',
       'Gender', 'Age range',
       'Self-defined ethnicity', 'Officer-defined ethnicity', 'Legislation',
       'Object of search', 'Outcome', 'Outcome linked to object of search',
        'station']

for col in rest:
    display(pd.crosstab(df['Outcome linked to object of search'], df[col], normalize="columns"))
# Out:
# Type                                Person and Vehicle search  Person search  \
# Outcome linked to object of search
# False                                                0.410911       0.480659
# True                                                 0.589089       0.519341
#
# Type                                Vehicle search
# Outcome linked to object of search
# False                                     0.505263
# True                                      0.494737
# Part of a policing operation           False     True
# Outcome linked to object of search
# False                               0.527694  0.552974
# True                                0.472306  0.447026
# Gender                               Female      Male     Other
# Outcome linked to object of search
# False                               0.51172  0.459719  0.608696
# True                                0.48828  0.540281  0.391304
# Age range                              10-17     18-24     25-34   over 34  \
# ...

# %%
rest = ['Type',  'Part of a policing operation',
       'Gender', 'Age range',
       'Self-defined ethnicity', 'Officer-defined ethnicity', 'Legislation',
       'Object of search', 'Outcome', 'Outcome linked to object of search',
        'station']

for col in rest:
    display(pd.crosstab(df['Removal of more than just outer clothing'], df[col], normalize="columns"))
# Out:
# Type                                      Person and Vehicle search  \
# Removal of more than just outer clothing
# False                                                      0.948079
# True                                                       0.051921
#
# Type                                      Person search  Vehicle search
# Removal of more than just outer clothing
# False                                          0.956325        0.980392
# True                                           0.043675        0.019608
# Part of a policing operation                 False     True
# Removal of more than just outer clothing
# False                                     0.957947  0.944785
# True                                      0.042053  0.055215
# Gender                                     Female      Male  Other
# Removal of more than just outer clothing
# False                                     0.94392  0.955613   0.94
# ...
